# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv', index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(bins=20, edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.bar()
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.line(y=['a','b'],figsize=(10,4),lw=2)
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*50,alpha=0.4, c='D', cmap='coolwarm')
# Out:
# d:\workspace\Coding\udemy\time series\venv\lib\site-packages\matplotlib\collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.boxplot()
# Out:
# <Axes: >

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df
# Out:
#             a         b
# 0    0.539965  0.433845
# 1   -1.324420  0.063371
# 2    0.857177 -0.997297
# 3   -0.168631 -0.236798
# 4   -0.298452 -0.158320
# ..        ...       ...
# 995  0.473035 -1.415480
# 996 -0.190578  1.987474
# 997  1.800459  0.829221
# 998 -0.936326  1.256461
# 999 -0.350673 -0.358128
#
# [1000 rows x 2 columns]

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ## Customizing Plots
